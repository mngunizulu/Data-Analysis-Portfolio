# %% [markdown]
# # 01. Importing Libraries

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Dataframes

# %%
path = r'C:\Users\mngun\Documents\11_2023_InstaCart_asket_Analysis'

# %%
df_ords = pd.read_csv(os.path.join(path,'02_Data','Original Data','orders.csv'),index_col = False)

# %%
df_prods = pd.read_csv(os.path.join(path,'02_Data','Original Data','products.csv'),index_col = False)

# %% [markdown]
# # 03. Data Wrangling

# %%
# dropping eval_set column (unnecessary)
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# counting missing values
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# days_since_prior_order
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: count, dtype: int64

# %%
# renaming a column
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# changing the order_id column to string
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
# importing the departments dataframe
df_depart = pd.read_csv(os.path.join(path,'02_Data','Original Data','departments.csv'),index_col = False)

# %%
# transposing and replacing df_depart 
df_depart_T = df_depart.T

# %%
df_depart_T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# correction of the headings
df_depart_T.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Taking the first row of df_depart_T for a new header
new_header = df_depart_T.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# Take the data below header for a new dataframe
df_depart_T_new = df_depart_T[1:]

# %%
df_depart_T_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# Set the header row as the dataframe header
df_depart_T_new.columns = new_header

# %%
df_depart_T_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Creating a data dictionary
data_dict = df_depart_T_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
# creating a subset
df_snacks = df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %% [markdown]
# # 04. Task

# %%
df_ords.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Question 2. converting user_id to a string
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
# Question 3. changing name of order_hour_of_day column without overwriting original dataframe
df_ords_2 = df_ords.rename(columns = {'order_hour_of_day':'hour_of_day'}, inplace = False)

# %%
df_ords_2
# Out:
#         order_id user_id  order_number  orders_day_of_week  hour_of_day  \
# 0        2539329       1             1                   2            8
# 1        2398795       1             2                   3            7
# 2         473747       1             3                   3           12
# 3        2254736       1             4                   4            7
# 4         431534       1             5                   4           15
# ...          ...     ...           ...                 ...          ...
# 3421078  2266710  206209            10                   5           18
# 3421079  1854736  206209            11                   4           10
# 3421080   626363  206209            12                   1           12
# 3421081  2977660  206209            13                   1           12
# 3421082   272231  206209            14                   6           14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
# Question 4. Finding the frquency for the variable hour_of_day
df_ords_2['hour_of_day'].value_counts(dropna = False)
# Out:
# hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# The busiest time for placing orders is 10 AM

# %%
# Question 5. Determine value of 4 in department_id column
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
#Question 6. create subset for breakfast item sales
df_breakfast_sales = df_prods[df_prods['department_id']==14]

# %%
df_breakfast_sales
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
# Question 7. Creating subset with multiple department_id's
df_multiple_sales = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_multiple_sales
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
# Question 8. Count the number of rows in the dataframe 
df_multiple_sales.shape
# Out:
# (7650, 5)

# %%
# Question 9. Creating a dataframe for user_id_1
df_user_id_1 = df_ords_2[df_ords_2['user_id']==1]

# %%
# user_id_1 has all missing values
df_user_id_1
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, hour_of_day, days_since_prior_order]
# Index: []

# %%
# Question 10. Basic Stats describing user_id_1
df_user_id_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                0 non-null      object
#  1   user_id                 0 non-null      object
#  2   order_number            0 non-null      int64
#  3   orders_day_of_week      0 non-null      int64
#  4   hour_of_day             0 non-null      int64
#  5   days_since_prior_order  0 non-null      float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 0.0+ bytes

# %%
# Question 12. Export data frame df_ords
df_ords.to_csv(os.path.join(path,'02_Data','Prepared Data','orders_wrangled.csv'))

# %%
# Question 13. Export data frame df_depart_T_new
df_depart_T_new.to_csv(os.path.join(path,'02_Data','Prepared Data','departments_wrangled.csv'))
