# %% [markdown]
# # 4.7 Deriving columns

# %% [markdown]
# Content
# 1. Importing Libraries
# 2. Importing Dataframes
# 3. If Statement
# 4. Applying if-statement through loc() function
# 5. Exercise 4.7
# 6. Exporting Dataframe

# %% [markdown]
# # 01. Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Dataframes

# %%
# Define path
path = r'C:\Users\mngun\Documents\11_2023_InstaCart_asket_Analysis'

# %%
# importing the ords_prods_merge dataframe
ords_prods_merge= pd.read_pickle(os.path.join(path,'02_Data','Prepared Data','ords_prods_merge.pkl'))

# %%
# looking at columns in dataframe
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_purchase  product_id  add_to_cart_order  \
# 0                     NaN            True         196                  1
# 1                    15.0           False         196                  1
# 2                    21.0           False         196                  1
# 3                    29.0           False         196                  1
# 4                    28.0           False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge
# ...

# %% [markdown]
# # 03. If Statement

# %%
# create a subset of first 1,000,000 rows
df = ords_prods_merge[:1000000]

# %%
# checking shape of dataframe
df.shape
# Out:
# (1000000, 15)

# %%
# create a user-defined function
def price_label(row):
    
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] >5) and (row['prices'] <=15):
        return 'Mid-range product'
    elif row['prices'] >15:
        return 'High-range product'
    else : return 'Not enough data'

# %%
# insert the new column and apply the function
df['price_range'] = df.apply(price_label,axis=1)
# Out:
# C:\Users\mngun\AppData\Local\Temp\ipykernel_15880\1402325726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label,axis=1)

# %%
# frequency of values in prace_range column
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
# retrieve the highest value in prices column
df['prices'].max()
# Out:
# 14.8

# %%
# looking at columns in dataframe
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_purchase  product_id  add_to_cart_order  \
# 0                     NaN            True         196                  1
# 1                    15.0           False         196                  1
# 2                    21.0           False         196                  1
# 3                    29.0           False         196                  1
# 4                    28.0           False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %% [markdown]
# # 04. Applying if-statement through loc() function

# %%
# applying .loc to high range 
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
# applying .loc to mid range 
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
# applying .loc to low range 
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# count of values
df['price_range_loc'].value_counts()
# Out:
# price_range_loc
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
# applying .loc to whole dataframe for 'High-range Product'
ords_prods_merge.loc[(ords_prods_merge['prices'] > 15), 'price_range_loc'] = 'High-range Product'

# %%
# applying .loc to whole dataframe for 'Mid-range Product'
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range Product'

# %%
# applying .loc to whole dataframe for 'Low-range Product'
ords_prods_merge.loc[(ords_prods_merge['prices'] <5), 'price_range_loc'] = 'Low-range Product'

# %%
# frequencies for price_range_loc
ords_prods_merge['price_range_loc'].value_counts()
# Out:
# price_range_loc
# Mid-range Product     21860860
# Low-range Product      9900417
# High-range Product      417678
# Name: count, dtype: int64

# %%
# frequency count of values in column
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# using if-statement to create labels based on values in orders_day_of_week column
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
# print the results
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# assigning the new column name where result will be put
ords_prods_merge['busiest_day'] = result

# %%
# checking frequency of 'busiest_day' column
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# # 05. Exercise 4.7

# %% [markdown]
# Question 2

# %%
# creating new labels and if conditions for orders_day_of_week column
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0 :
    result.append("Busiest days")
  elif value == 1:
    result.append("Busiest days")
  elif value == 3:
    result.append('Slowest days')
  elif value == 4:
    result.append('Slowest days')
  else:
    result.append("Regularly busy")

# %%
# creating the column for the new row labels
ords_prods_merge['busy_days'] = result

# %% [markdown]
# Question 3

# %%
# frequency for new column 'busy_days'
ords_prods_merge['busy_days'].value_counts(dropna = False)
# Out:
# busy_days
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: count, dtype: int64

# %%
# checking shape of dataframe
ords_prods_merge.shape
# Out:
# (32404859, 18)

# %% [markdown]
# Comments:
# - All the rows have been categorised into one of the 3 labels
# - The previously created column remains in the dataframe and is not overwritten

# %%
# looking at columns in dataframe
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_purchase  product_id  add_to_cart_order  \
# 0                     NaN            True         196                  1
# 1                    15.0           False         196                  1
# 2                    21.0           False         196                  1
# 3                    29.0           False         196                  1
# 4                    28.0           False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %% [markdown]
# Question 4. Creating a 'busiest_period_of_day' column

# %%
# finding the frequency for values in column 'order_hour_of_day'
ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
# using the .loc() function to create column name and assign labels  
ords_prods_merge.loc[ords_prods_merge['order_hour_of_day'].isin([9,10,11,12,13,14,15,16]), 'busiest_period_of_day'] = 'Most Orders'

# %%
# using the .loc() function to create column name and assign labels  
ords_prods_merge.loc[ords_prods_merge['order_hour_of_day'].isin([0,1,2,3,4,5,6,23]), 'busiest_period_of_day'] = 'Fewest Orders'

# %%
# using the .loc() function to create column name and assign labels  
ords_prods_merge.loc[ords_prods_merge['order_hour_of_day'].isin([7,8,17,18,19,20,21,22]), 'busiest_period_of_day'] = 'Average Orders'

# %% [markdown]
# Question 5. Print frequency for the new column

# %%
# table of frequencies in column 'busiest_period_of_day'
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most Orders       21118071
# Average Orders     9997651
# Fewest Orders      1289137
# Name: count, dtype: int64

# %%
# checking dataframe
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_purchase  product_id  add_to_cart_order  \
# 0                     NaN            True         196                  1
# 1                    15.0           False         196                  1
# 2                    21.0           False         196                  1
# 3                    29.0           False         196                  1
# 4                    28.0           False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %% [markdown]
# # 06. Exporting Dataframe

# %%
# export final dataframe to pickle
ords_prods_merge.to_pickle(os.path.join(path, '02_Data','Prepared Data','ords_prods_custom.pkl'))
